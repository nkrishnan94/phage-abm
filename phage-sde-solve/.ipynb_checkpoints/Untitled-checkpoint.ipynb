# %%
import glob
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
vf = glob.glob("vel*.txt")
af = glob.glob("abs*.txt")

# %%
#plt.plot(np.diff(np.loadtxt(vf[0])[:,1]))
plt.plot(np.diff(np.loadtxt(af[0])[:,1])[1:])

# %%
np.mean(np.diff(np.loadtxt(af[0])[:,1])[1:])*200
# Out:
# 1947611.111111111

# %%
np.mean(np.diff(np.loadtxt(vf[0])[:,1]))
# Out:
# -481.94472361809045

# %%
vf
# Out:
# ['velocity_Nb100_migr0.25+_tau2_alpha0.01_ID0_demes200_2021-01-26-13-33-34.txt']

# %%
np.mean((np.diff(np.loadtxt(af[0])/np.diff(np.loadtxt(vf[0]))))p[])
# Out:
#   File "<ipython-input-506-4e3fd2084669>", line 1
#     np.mean((np.diff(np.loadtxt(af[0])/np.diff(np.loadtxt(vf[0]))))p[])
#                                                                    ^
# SyntaxError: invalid syntax

# %%
np.diff(np.loadtxt(vf[0])[:,1])
# Out:
# array([-9.6123e+04,  2.1200e+02, -2.8600e+02,  4.0800e+02, -1.2940e+03,
#        -1.7600e+02,  8.2600e+02, -3.9700e+02,  1.8400e+02,  1.1530e+03,
#        -1.5790e+03,  7.8400e+02,  5.6600e+02, -2.0000e+02, -4.5200e+02,
#        -2.0300e+02,  5.2700e+02,  4.2900e+02, -1.2070e+03,  8.7000e+01,
#        -1.1420e+03,  1.8780e+03, -4.1400e+02, -3.7800e+02, -4.7000e+01,
#         3.9100e+02, -4.9200e+02,  6.7000e+01, -9.7000e+01,  1.3630e+03,
#        -9.7900e+02,  1.4610e+03, -2.3580e+03,  6.4700e+02,  1.0540e+03,
#         1.5000e+01, -5.5600e+02,  9.4300e+02, -2.1220e+03,  1.1400e+03,
#         5.4700e+02, -1.7680e+03,  1.8250e+03, -3.2200e+02, -1.1600e+03,
#        -4.9400e+02,  1.4170e+03,  1.1770e+03, -1.2560e+03, -2.7500e+02,
#        -3.0500e+02,  1.5130e+03, -4.2100e+02, -8.3900e+02,  5.6500e+02,
#        -4.9200e+02, -9.8000e+02,  1.8360e+03,  8.7400e+02, -1.2620e+03,
#         7.2200e+02, -1.2570e+03, -1.2000e+01,  9.6200e+02, -2.6820e+03,
#         1.6980e+03,  8.5300e+02, -1.0190e+03, -8.6200e+02,  8.2300e+02,
#        -2.5300e+02, -3.2200e+02,  4.2500e+02,  8.6000e+02, -7.9600e+02,
#         4.9900e+02,  1.2400e+02, -3.0100e+02, -5.7500e+02,  1.9500e+03,
#        -1.9030e+03,  8.9000e+02, -3.5600e+02,  6.9300e+02, -8.0900e+02,
#         1.8600e+02, -1.3800e+02,  1.1270e+03, -1.4330e+03,  1.4010e+03,
#        -1.6860e+03,  6.9900e+02, -6.6000e+01,  6.8000e+01,  5.6500e+02,
#         1.3200e+02, -2.0700e+02,  3.5800e+02, -1.9580e+03,  2.0490e+03,
#        -7.3700e+02,  5.1700e+02, -1.1710e+03,  1.5750e+03, -1.1050e+03,
#        -2.4300e+02,  4.7200e+02,  6.9700e+02,  8.9000e+01, -1.4410e+03,
#         6.6000e+01,  5.4400e+02,  5.9500e+02, -6.6600e+02, -3.0000e+01,
#        -1.1760e+03,  9.5300e+02,  1.1240e+03, -7.1000e+01, -1.9380e+03,
#        -9.7100e+02,  1.5320e+03, -5.2000e+02,  1.5250e+03,  5.4700e+02,
#        -1.8650e+03,  9.4100e+02,  5.8300e+02, -2.1000e+02, -1.0030e+03,
#         1.3460e+03, -1.2200e+02, -3.0000e+00, -1.0060e+03, -6.4400e+02,
#        -5.1900e+02,  1.8400e+03,  6.3000e+02, -4.7400e+02, -4.0000e+02,
#        -5.0400e+02,  7.0400e+02, -1.4900e+02,  7.8700e+02, -9.2100e+02,
#        -1.3000e+01,  2.7800e+02,  9.0000e+00,  1.1600e+02,  1.6300e+02,
#        -7.7900e+02, -2.7900e+02,  5.9200e+02,  5.8500e+02, -1.3070e+03,
#         6.9700e+02,  3.3000e+02,  4.9000e+01, -4.0500e+02,  4.1000e+01,
#        -5.2600e+02,  4.7100e+02, -1.0900e+02,  9.2900e+02, -1.2070e+03,
#         6.3500e+02,  7.7000e+02, -2.4220e+03,  1.0870e+03,  4.9600e+02,
#        -1.1920e+03,  2.2080e+03, -8.7600e+02, -6.6500e+02,  3.2100e+02,
#        -1.0040e+03,  8.9700e+02,  2.5100e+02, -6.7000e+02,  5.0300e+02,
#        -3.4200e+02, -8.3900e+02,  3.0600e+02,  2.2220e+03, -1.7430e+03,
#        -3.0200e+02,  9.2200e+02,  5.6000e+01,  7.6400e+02, -1.6510e+03,
#         1.9920e+03, -1.6500e+03,  9.1400e+02, -1.7890e+03,  8.8800e+02,
#         4.5300e+02, -1.4310e+03,  7.9300e+02,  1.1160e+03])

# %%
np.mean((np.diff(np.loadtxt(af[0])[:,1])/500)[30:])/(np.mean((np.loadtxt(vf[0])[:,1])[30:])/500)
# Out:
# 0.09404026157960092

# %%
(np.mean((np.loadtxt(vf[0])[:,1])[30:])/500)
# Out:
# 207.1238

# %%
np.diff(np.loadtxt(af[0])[:,1])/500)[20:
# Out:
#   File "<ipython-input-482-9e96edf0e1c9>", line 1
#     np.diff(np.loadtxt(af[0])[:,1])/500)[20:
#                                        ^
# SyntaxError: unmatched ')'

# %%
.03
# Out:
# 0.03

# %%
0.03*1 *200
# Out:
# 6.0

# %%
2500*0.03
# Out:
# 75.0

# %%
(np.mean(np.diff(np.loadtxt(af[0])[:,1])[20:]/np.diff(np.loadtxt(vf[0])[:,1])[20:]))*25*50
# Out:
# <ipython-input-402-5a4db9469bc3>:1: UserWarning: loadtxt: Empty input file: "abs_Nb200_migr0.25_B+_tau2_alpha0.03_ID0_demes200_2021-01-26-13-25-51.txt"
#   (np.mean(np.diff(np.loadtxt(af[0])[:,1])[20:]/np.diff(np.loadtxt(vf[0])[:,1])[20:]))*25*50
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-402-5a4db9469bc3> in <module>
# ----> 1 (np.mean(np.diff(np.loadtxt(af[0])[:,1])[20:]/np.diff(np.loadtxt(vf[0])[:,1])[20:]))*25*50
#
# IndexError: too many indices for array

# %%
(np.mean(np.diff(np.loadtxt(af[0])[:,1])[20:]/np.diff(np.loadtxt(vf[0])[:,1])[20:]))
# Out:
# <ipython-input-403-64818c5c273d>:1: UserWarning: loadtxt: Empty input file: "abs_Nb200_migr0.25_B+_tau2_alpha0.03_ID0_demes200_2021-01-26-13-25-51.txt"
#   (np.mean(np.diff(np.loadtxt(af[0])[:,1])[20:]/np.diff(np.loadtxt(vf[0])[:,1])[20:]))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-403-64818c5c273d> in <module>
# ----> 1 (np.mean(np.diff(np.loadtxt(af[0])[:,1])[20:]/np.diff(np.loadtxt(vf[0])[:,1])[20:]))
#
# IndexError: too many indices for array

# %%
plt.plot(np.diff(np.loadtxt(af[0])[:,1])[20:])
# Out:
# <ipython-input-404-e9da1b292c5e>:1: UserWarning: loadtxt: Empty input file: "abs_Nb200_migr0.25_B+_tau2_alpha0.03_ID0_demes200_2021-01-26-13-25-51.txt"
#   plt.plot(np.diff(np.loadtxt(af[0])[:,1])[20:])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-404-e9da1b292c5e> in <module>
# ----> 1 plt.plot(np.diff(np.loadtxt(af[0])[:,1])[20:])
#
# IndexError: too many indices for array

# %%
af
# Out:
# ['abs_Nb50_migr0.25_B+_tau25_alpha0.03_ID0_demes200_2021-01-26-13-10-29.txt']

# %%
plt.plot(np.loadtxt(af[0])[:,1] / np.loadtxt(vf[0])[:,1])
