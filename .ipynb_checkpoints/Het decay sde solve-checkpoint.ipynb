# %%
import matplotlib.pyplot
import numpy as np
import glob
import os
import matplotlib.pyplot as plt

# %%
hetf = glob.glob('/Users/nikhilkrishnan/Dropbox/Research/PhD/phage_ibm/het_data_sde/hetero*')
velf = glob.glob('/Users/nikhilkrishnan/Dropbox/Research/PhD/phage_ibm/het_data_sde/velocity*')

# %%
hetf
# Out:
# ['/Users/nikhilkrishnan/Dropbox/Research/PhD/phage_ibm/het_data_sde/hetero_Nb25_migr0.25+_tau100_alpha0.03_ID21_demes200_2021-01-28-03-15-58.txt',
#  '/Users/nikhilkrishnan/Dropbox/Research/PhD/phage_ibm/het_data_sde/hetero_Nb25_migr0.25+_tau200_alpha0.03_ID21_demes200_2021-01-28-04-45-22.txt',
#  '/Users/nikhilkrishnan/Dropbox/Research/PhD/phage_ibm/het_data_sde/hetero_Nb25_migr0.25+_tau200_alpha0.03_ID41_demes200_2021-01-28-05-07-54.txt',
#  '/Users/nikhilkrishnan/Dropbox/Research/PhD/phage_ibm/het_data_sde/hetero_Nb50_migr0.25+_tau100_alpha0.03_ID45_demes200_2021-01-27-05-19-56.txt',
#  '/Users/nikhilkrishnan/Dropbox/Research/PhD/phage_ibm/het_data_sde/hetero_Nb25_migr0.25+_tau500_alpha0.03_ID78_demes200_2021-01-28-05-53-00.txt',
#  '/Users/nikhilkrishnan/Dropbox/Research/PhD/phage_ibm/het_data_sde/hetero_Nb50_migr0.25+_tau50_alpha0.03_ID1_demes200_2021-01-27-04-58-08.txt',
# ...

# %%
taus = np.array([50,100,200])
Bsims= np.array([25,50])
samps = 100

# %%
harr = np.zeros((len(Bsims),len(taus), samps,5000 ))

for t, tau in enumerate(taus):
    for B, Bsim in enumerate(Bsims):
        for ID in range(1,samps+1):
            hetf = glob.glob('/Users/nikhilkrishnan/Dropbox/Research/PhD/phage_ibm/het_data_sde/hetero*Nb'+str(Bsim)+'*tau'+str(tau)+'_*ID'+str(ID)+'*')
            arr = np.loadtxt(hetf[0])[:,1]
            harr[B,t,ID-1,:len(arr)]=arr

# %%
fig,ax = plt.subplots()
colors = ['navy', 'orange', 'purple', 'maroon','grey']
for i in range(3):
    ax.plot(np.mean(harr[0,i,:,:500],axis=0),lw=3,c = colors[i],label=r'$\tau$ = '+str(taus[i]))
    ax.plot(np.mean(harr[1,i,:,:500],axis=0),lw=3,c = colors[i],label=r'$\tau$ = '+str(taus[i]))



for axis in ['left','bottom']:
    ax.spines[axis].set_linewidth(2)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_xlabel('Time (time steps)',fontsize=20)
ax.set_ylabel('H',fontsize=20)
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
ax.legend()

# %%
plt.plot(np.log(np.mean(harr[0,0,:,:1000],axis=0)))
plt.plot(np.log(np.mean(harr[1,0,:,:1000],axis=0)))
# Out:
# <ipython-input-136-a4873c2cdc5e>:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.mean(harr[0,0,:,:1000],axis=0)))
# <ipython-input-136-a4873c2cdc5e>:2: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(np.mean(harr[1,0,:,:1000],axis=0)))

# %%
tf = [80,100,150]
ts=[50,50,50]
rates = []

for i in range(3):
    rate = -np.polyfit(np.arange(tf[i]-ts[i]),np.log(np.mean(harr[i,:,ts[i]:tf[i]],axis=0)),1)[0]
    rates.append(rate)

# %%
rates
# Out:
# [0.2552297155148313, 0.14047105920397535, 0.0870444799597354]

# %%
fig,ax= plt.subplots()
ax.scatter(taus,rates,marker = 'x',s=200)



for axis in ['left','bottom']:
    ax.spines[axis].set_linewidth(2)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_xlabel(r'$\tau$',fontsize=20)
ax.set_ylabel(r'$\Lambda$',fontsize=20)
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
ax.grid()

#ax.set_xscale('log')

#ax.set_yscale('log')

# %%
rates
# Out:
# [0.024084813430133797, 0.010228271850064304, 0.0019184969985088858]
